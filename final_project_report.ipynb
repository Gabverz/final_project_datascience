# %% [markdown]
# # Revisão de código
#
# Olá!
#
# Meu nome é Suelen. Estou feliz em revisar seu projeto hoje!
#
# Quando vejo um erro pela primeira vez, apenas aponto. Deixarei você encontrá-lo e corrigi-lo sozinho. Além disso, ao longo do texto, farei algumas observações sobre melhorias no código e também farei comentários sobre suas percepções sobre o assunto. Mas se você ainda não consegue lidar com essa tarefa, darei uma dica mais precisa na próxima iteração e também alguns exemplos práticos. Estarei aberto a feedbacks e discussões sobre o tema.
#
# Você pode encontrar meus comentários em caixas verdes, amarelas ou vermelhas como estas:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo está correto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Observações. Algumas recomendações.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# O bloco requer algumas correções. O trabalho não pode ser aceito com os comentários vermelhos.
# </div>
#
# Você pode me responder usando isto:
#
# <div class="alert alert-block alert-info">
# <b>Resposta do aluno.
#     </b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#   <b>Comentário geral:</b> <a class="tocSkip"></a>
#
#   Parabéns pelo projeto, Gabriel! Ele cobre muito bem todas as etapas de um projeto de ciência de dados, desde a análise exploratória até a modelagem.
#
#   Como sugestões de melhoria e próximos passos, vale considerar:
#   <ul>
#     <li>Investir em feature engineering adicional, incluindo variáveis temporais (dia da semana, sazonalidade), distância da rota e tipo de voo.</li>
#     <li>Melhorar a codificação de variáveis categóricas, usando <code>pd.get_dummies()</code>, target encoding ou embeddings.</li>
#     <li>Ajustar hiperparâmetros com Grid Search ou Random Search.</li>
#     <li>Avaliar o tratamento de outliers e a seleção de features para reduzir ruído.</li>
#   </ul>
#   <br>
#   No mais, é um ótimo projeto!
#   <br><br>
#   Adicionei alguns comentários e respostas às suas perguntas ao final do notebook. :)
# </div>

# %% [markdown]
# # Projeto de Conclusão de Curso - Data Science - Tripleten
#
# - Aluno: Gabriel Chaves Veras
# - Turma: DS25
#
# # Plano de trabalho
#
# ### Descrição do problema
#
# - #### Objetivo
# A planta siderúrgica **Steelproof** busca **otimizar seus custos de produção** reduzindo o consumo de energia durante a etapa de **processamento do aço**.
#
# O objetivo deste trabalho será **desenvolver um modelo capaz de prever a temperatura do metal**, auxiliando a planta a tomar decisões mais eficientes e sustentáveis em seu processo industrial.
#
#
# - #### Descrição breve do processo produtivo
#
#
# O aço é processado em uma **panela metalúrgica** com capacidade aproximada de **100 toneladas**.
# Para suportar as altas temperaturas, o interior da panela é revestido com **tijolos refratários**.
#
# 1. **Fusão e aquecimento:**
#
#     O aço fundido é despejado na panela e aquecido até atingir a temperatura desejada por meio de **eletrodos de grafite** localizados na tampa.
#
# 2. **Dessulfurização:**
#
#     O enxofre é removido do metal através de um processo químico especializado, aumentando sua pureza e qualidade.
#
# 3. **Ajuste químico:**
#
#     A composição do aço é corrigida pela adição de **ligas metálicas**, em forma de lingotes adicionados a partir de um búnquer ou por meio de um **alimentador de arame**. Durante esse processo, também são retiradas **amostras** para análise.
#
# 4. **Controle de temperatura e composição:**
#
#     Antes da adição dos elementos de liga, são feitas **medições de temperatura** e análises de **composição química**. Em seguida, o aço é aquecido por alguns minutos adicionais, os elementos necessários são adicionados e a liga é **purgada com gás inerte**.
#
# 5. **Homogeneização:**
#
#     Após a purga, a liga é **agitada e a temperatura é medida novamente**. Esse ciclo se repete várias vezes até que se alcance a **composição química desejada** e a **temperatura ideal de fusão**.
#
#
# Por fim, o aço fundido é **refinado** ou transferido para uma **máquina de lingotamento contínuo**, onde se solidifica formando **placas** que serão utilizadas em etapas posteriores da manufatura.
#
# - #### Descrição dos dados utilizados
#
# Os dados provêm de **múltiplas fontes**, que registram diferentes etapas do processo:
#
# - `data_arc_en.csv` — dados dos eletrodos.
# - `data_bulk_en.csv` — informações sobre o fornecimento de materiais a granel (volume).
# - `data_bulk_time_en.csv` — tempos de entrega de materiais a granel.
# - `data_gas_en.csv` — dados do processo de purga de gás.
# - `data_temp_en.csv` — registros de medições de temperatura.
# - `data_wire_en.csv` — dados sobre os materiais em arame (volume).
# - `data_wire_time_en.csv` — tempos de entrega dos materiais em arame.
#
# 📌 Em todos os arquivos, a coluna **`key`** representa o **número do lote**.
#
# É possível encontrar **múltiplas linhas com o mesmo valor em `key`**, já que cada uma corresponde a **diferentes iterações do processo de tratamento do aço**.

# %% [markdown]
# ### Contexto e motivação
#
# A produção de aço data de aproximadamente 3000 anos a.C., com os primeiros exemplos de materiais surgindo no Oriente Médio. A combinação do ferro com carbono resultou em um material mais resistente que o ferro puro, marcando o início de sua produção. Egípcios, babilônios e, posteriormente, os romanos, reconheciam sua dureza e maleabilidade, empregando-o em espadas, lanças e ferramentas agrícolas. O aço tornou-se essencial para a guerra e a agricultura, impulsionando o desenvolvimento econômico e militar.
#
# Após anos de desenvolvimento tecnológico, teve na Revolução Industrial do século XVIII e XIX seu ápice, onde inovações trouxeram desenvolvimento significativo e escalabilidade ao produto, como a fabricação de aço em massa pelo processo de Bessemer, que tornou-o mais acessível. No século XX, o aço se tornou a espinha dorsal da industrialização moderna. Sua utilização se expandiu para a construção civil, transporte (trens, navios), e infraestruturas (pontes, edifícios). O aço é, hoje, um componente essencial na fabricação de automóveis e em tecnologias emergentes, como energias renováveis.[1](https://worldsteel.org/)
#
# Apesar do desenvolvimento pulsante e da crescente relação de importância do aço com o crescimento global, atualmente sua produção tem alto impacto em sustentabilidade: quando se considera o ciclo produtivo completo (incluindo as emissões indiretas de eletricidade e a cadeia de suprimentos), aproximadamente 9% das emissões globais de $CO_2$ são provenientes da indústria do aço, o equivalente a 2,6 gigatoneladas. Desta forma, a comunicade global estipulou metas agressivas para mitigação do risco ambiental latente referente à indústria do aço. Até 2030, espera-se reduzir a intensidade de emissões de $CO_2$ em cerca de 25% a 30% em relação aos níveis atuais. Para 2050, a meta é de 90%[2](https://www.iea.org/reports/iron-and-steel-technology-roadmap)
#
# Para conseguir conciliar o avanço na questão ambiental com a sustentabilidade do negócio, torna-se indispensável a busca por otmizações de processo que consigam reduzir custos. A transição para Fornos a Arco Elétrico (EAF), que são mais limpos que os altos-fornos, aumentou drasticamente a dependência de eletricidade, e atualmente a instabilidade nos preços de energia e a necessidade de fontes 100% renováveis tornam o custo operacional muito sensível. Há ainda o fato de que esta eletrificação da siderurgia exige uma capacidade de carga que muitas redes nacionais ainda não suportam, trazendo insegurança ao contexto das companhias.[2](https://www.iea.org/reports/iron-and-steel-technology-roadmap)
#
# Sendo assim, atingir todas estas metas ambiciosas em paralelo ao crescimento sustentável do negócio só é possível intensificando de maneira acelerada o entendimento profundo do processo produtivo, e cada vez mais a ciência de dados, por meio de análises preditivas, consegue trabalhar parâmetros de processo de modo a otimizar variáveis-chave que tragam este ganho. Isto já vem sendo realizado: A Gerdau, gigante no setor de siderurgia, reportou um projeto focado otimização da carga metálica e consumo de combustível, resultando em redução direta de custos operacionais por meio de modelos preditivos que analisam o desempenho e consumo energético dos altos-fornos.[3](https://www.cassotis.com/cases/gerdau-longos)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Boa introdução do problema!

# %% [markdown]
# ### ANÁLISE EXPLORATÓRIA DE DADOS

# %%
# Importando bibliotecas úteis nesta etapa:
import pandas as pd

# %%
# Carregando dados e transformando em dataframe Pandas:
data_arc = pd.read_csv('data_arc_en.csv')
data_bulk = pd.read_csv('data_bulk_en.csv')
data_bulk_time = pd.read_csv('data_bulk_time_en.csv')
data_gas = pd.read_csv('data_gas_en.csv')
data_temp = pd.read_csv('data_temp_en.csv')
data_wire = pd.read_csv('data_wire_en.csv')
data_wire_tim = pd.read_csv('data_wire_time_en.csv')

# %%
# Analisando e tratando dados do DF data_arc:

print(data_arc.info())
print()
print(data_arc.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                14876 non-null  int64
#  1   Arc heating start  14876 non-null  object
#  2   Arc heating end    14876 non-null  object
#  3   Active power       14876 non-null  float64
#  4   Reactive power     14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 581.2+ KB
# None
#
#    key    Arc heating start      Arc heating end  Active power  Reactive power
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02      0.976059        0.687084
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33      0.805607        0.520285
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36      0.744363        0.498805
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19      1.659363        1.062669
# ...

# %%
# O DF não possui valores ausentes. Aparenta tratar do calor ativo e reativo de cada lote, porém mais informações
# são necessárias para entender exatamente do que se tratam os números apresentados. Há duas colunas de datas classificadas como
# 'object', portanto iremos tratá-las adequadamente:

data_arc['Arc heating start'] = pd.to_datetime(data_arc['Arc heating start'])
data_arc['Arc heating end'] = pd.to_datetime(data_arc['Arc heating end'])

# %%
data_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                14876 non-null  int64
#  1   Arc heating start  14876 non-null  datetime64[ns]
#  2   Arc heating end    14876 non-null  datetime64[ns]
#  3   Active power       14876 non-null  float64
#  4   Reactive power     14876 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(1)
# memory usage: 581.2 KB

# %%
# Analisando e tratando dados do DF data_bulk:

print(data_bulk.info())
print()
print(data_bulk.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    float64
#  2   Bulk 2   22 non-null     float64
#  3   Bulk 3   1298 non-null   float64
#  4   Bulk 4   1014 non-null   float64
#  5   Bulk 5   77 non-null     float64
#  6   Bulk 6   576 non-null    float64
#  7   Bulk 7   25 non-null     float64
#  8   Bulk 8   1 non-null      float64
#  9   Bulk 9   19 non-null     float64
#  10  Bulk 10  176 non-null    float64
#  11  Bulk 11  177 non-null    float64
#  12  Bulk 12  2450 non-null   float64
#  13  Bulk 13  18 non-null     float64
#  14  Bulk 14  2806 non-null   float64
#  15  Bulk 15  2248 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 391.2 KB
# None
#
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# ...

# %%
# O DF data_bulk possui inúmeros valores ausentes. Aparenta determinar o quantitativo produzido, porém
# é necessário entender a diferença entre cada um deles. Por enquanto é mais seguro não modificá-lo até
# termos plena compreensão dos seus dados.

# %%
# Analisando e tratando dados do DF data_bulk_time:
print(data_bulk_time.info())
print()
print(data_bulk_time.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    object
#  2   Bulk 2   22 non-null     object
#  3   Bulk 3   1298 non-null   object
#  4   Bulk 4   1014 non-null   object
#  5   Bulk 5   77 non-null     object
#  6   Bulk 6   576 non-null    object
#  7   Bulk 7   25 non-null     object
#  8   Bulk 8   1 non-null      object
#  9   Bulk 9   19 non-null     object
#  10  Bulk 10  176 non-null    object
#  11  Bulk 11  177 non-null    object
#  12  Bulk 12  2450 non-null   object
#  13  Bulk 13  18 non-null     object
#  14  Bulk 14  2806 non-null   object
#  15  Bulk 15  2248 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 391.2+ KB
# None
#
#    key Bulk 1 Bulk 2 Bulk 3               Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# ...

# %%
# O DF data_bulk_time possui inúmeros valores ausentes. É necessário entender a diferença entre cada um deles. 
# Por enquanto é mais seguro não modificá-lo até termos plena compreensão dos seus dados.

# %%
# Analisando e tratando dados do DF data_gas:

print(data_gas.info())
print()
print(data_gas.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Gas 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB
# None
#
#    key      Gas 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692
# 5    6  11.273392
# 6    7   9.836267
# 7    8  15.171553
# 8    9   8.216623
# 9   10   6.529891

# %%
# O DF data_bulk_time não possui valores ausentes e o tipo de dados é adequado. Aparentam se referir a uma quantidade
# de gás infusionada ao processo, porém mais detalhes precisam ser fornecidos.

# %%
# Analisando e tratando dados do DF data_temp:
print(data_temp.info())
print()
print(data_temp.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15907 entries, 0 to 15906
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   key            15907 non-null  int64
#  1   Sampling time  15907 non-null  object
#  2   Temperature    13006 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.9+ KB
# None
#
#    key        Sampling time  Temperature
# 0    1  2019-05-03 11:16:18       1571.0
# 1    1  2019-05-03 11:25:53       1604.0
# 2    1  2019-05-03 11:29:11       1618.0
# 3    1  2019-05-03 11:30:01       1601.0
# 4    1  2019-05-03 11:30:39       1613.0
# 5    2  2019-05-03 11:37:27       1581.0
# 6    2  2019-05-03 11:38:00       1577.0
# 7    2  2019-05-03 11:49:38       1589.0
# 8    2  2019-05-03 11:55:50       1604.0
# 9    2  2019-05-03 11:58:24       1608.0

# %%
# Checando se os dados em branco agregam valor ao dataframe:
data_temp[data_temp['Temperature'].isna()]
print(data_temp[data_temp['Temperature'].isna()].nunique())
print(data_temp.nunique())
# Out:
# key               739
# Sampling time    2901
# Temperature         0
# dtype: int64
# key               3216
# Sampling time    15907
# Temperature        175
# dtype: int64

# %%
# Removendo dados com valores nulos na coluna 'temperature'
df_data_temp = data_temp.dropna(subset=['Temperature'])
print(df_data_temp.nunique())
# Out:
# key               3216
# Sampling time    13006
# Temperature        175
# dtype: int64

# %%
df_data_temp['Temperature'] = pd.to_datetime(df_data_temp['Temperature'])
# Out:
# /tmp/ipykernel_34/2927821631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_temp['Temperature'] = pd.to_datetime(df_data_temp['Temperature'])

# %%
# 739 lotes apresentavam valores nulos de temperatura, o que pode indicar um mal funcionamento de algum sensor do processo.
# Como mantivemos todos os 3216 lotes iniciais, provavelmente a indústria coletava amostras em outros momentos para compensar
# este déficit. Vale a pena confirmar esta informação. Também ajustamos o tipo de dados de tempo para o dataframe.

# %%
# Analisando e tratando dados do DF data_wire:
print(data_wire.info())
print()
print(data_wire.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
#  7   Wire 7  11 non-null     float64
#  8   Wire 8  19 non-null     float64
#  9   Wire 9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB
# None
#
#    key      Wire 1     Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1   60.059998        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2   96.052315        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3   91.160157        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
# O dataframe data_wire refere-se provavelmente a uma das últimas etapas do processo produtivo, onde
# "cabos" de metal fundido passam por extrusoras para serem transformadas em lingotes e resfriadas. Os valores do DF
# precisam ser esclarecidos

# %%
# Analisando e tratando dados do DF data_wire_tim:
print(data_wire_tim.info())
print()
print(data_wire_tim.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB
# None
#
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:11:41                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:46:10                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:13:47                  NaN    NaN    NaN    NaN    NaN
# ...

# %%
# O DF data_wire_tim possui inúmeros valores ausentes. É necessário entender a diferença entre cada um deles. 
# Por enquanto é mais seguro não modificá-lo até termos plena compreensão dos seus dados.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário:</b> <a class="tocSkip"></a>
#
# EDA robusto e muito eficiente para gerar insights antes da construção do modelo. Parabéns pelo trabalho!
#
# Algumas sugestões para enriquecer ainda mais a análise:
#
# - Incluir a análise da distribuição das variáveis numéricas (histogramas, boxplots), o que ajuda a identificar assimetrias, outliers e possíveis transformações necessárias.
# - Avaliar o desbalanceamento de classes na variável alvo, utilizando gráficos de barras ou proporções, para entender se será necessário aplicar técnicas como reamostragem ou métricas específicas na etapa de modelagem.
# - Explorar relações entre variáveis (por exemplo, correlação ou comparações entre grupos), o que pode trazer insights importantes para a seleção de features.
#
#
#
# </div>

# %% [markdown]
# ### Perguntas para esclarecimento:
#
# 1- No dataframe data_arc, o que significa Active power e Reactive power? É seguro dizer que, se coletarmos os dados de primeiro horário de início e último horário de fim, temos o tempo total de produção?
#
#
#
# 2- No dataframe data_bulk, o que significa cada coluna? O que significam os valores em branco? Há sentido em somar todos para cada lote?
#
#
# 3- No dataframe data_bulk_time, o que significa cada coluna? Os valores datetime referem-se a que, exatamente?
#
#
#
# 4- No dataframe data_gas, o que significam os valores de Gas 1? Se referem a uma etapa específica do processo? Se sim, qual? Qual é este gás e qual a unidade de medida?
#
#
#
# 5- No dataframe data_temp, o que significam valores nulos de temperatura? Para cada lote há mais de um valor, isso representa o valor de temperatura para cada etapa do processo? Se não, o que significam?
#
#
#
#
#
# 6- No dataframe data_wire, o que significa cada coluna? O que significam os valores em branco? Há sentido em somar todos para cada lote?
#
#
#
# 7- No dataframe data_wire_tim, o que significa cada coluna? Os valores datetime referem-se a que, exatamente?
#
#
#
# 8- O valor-objetivo da análise deverá ser uma **temperatura**. Qual valor de temperatura devemos utilizar como target? Seria a coluna df_data_temp['Temperature']? Deseja-se entender a temperatura de alguma etapa específica do processo, de todas ou a diferença de temperatura entre eles (qual abordagem entregaria maior ganho?)?
#
#
#
# 9- Devemos utilizar o tempo como Feature? No caso, seria o valor bruto ou a diferença entre os horários de cada etapa produtiva?
#
# 10- Há alguma variável que possivelmente tem um peso maior ou menor na análise? Alguma deve ser desconsiderada?
#
#
#
# 11- Existe algum método preditivo específico preferido pelo cliente ou devemos escolher mediante a construção do projeto?
# As escolhas preditivas são sempre escolha do profissional de dados. Utilize todo o seu conhecimento para escolher o modelo que é mais adequado para o caso.
#
# 12- Como devemos calcular o potencial de ganho com o projeto?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Comentário:</b> <a class="tocSkip"></a>
#
# Oi Gabriel! Seguem abaixo as perguntas e respostas. Gostaria de ressaltar que não tenho conhecimento desse dataframe que está sendo utilizado no projeto, então inferi a partir da análise exploratória realizada no projeto:
#
# ---
#
# ### 1- No dataframe data_arc, o que significa Active power e Reactive power? É seguro dizer que, se coletarmos os dados de primeiro horário de início e último horário de fim, temos o tempo total de produção?
#
# Active power é a potência efetivamente usada no processo (a energia que gera trabalho, como aquecimento e operação dos equipamentos). Já Reactive power é a potência necessária para manter o funcionamento elétrico dos sistemas, mas que não realiza trabalho direto.
#
# Não é seguro considerar o tempo total apenas pela diferença entre o primeiro início e o último fim. Esse intervalo pode incluir pausas ou períodos sem operação. O mais correto é somar a duração de cada evento de aquecimento individual para obter o tempo real de produção.
#
# ---
#
# ### 2- No dataframe data_bulk, o que significa cada coluna? O que significam os valores em branco? Há sentido em somar todos para cada lote?
#
# Cada linha representa um lote (`key`) e as colunas `Bulk 1` a `Bulk 15` indicam a quantidade de cada tipo de material adicionada. Valores em branco (`NaN`) apenas indicam que aquele material não foi usado no lote.
#
# Somar os bulks por lote faz sentido para obter o total de material adicionado, mas é importante também analisar os materiais separadamente, já que cada um pode impactar o processo de forma diferente.
#
# ---
#
# ### 3- No dataframe data_bulk_time, o que significa cada coluna? Os valores datetime referem-se a que, exatamente?
#
# Cada linha representa um lote e as colunas `Bulk 1` a `Bulk 15` indicam o horário exato em que cada material foi adicionado. Valores `NaN` significam que o material não foi utilizado.
#
# Os valores datetime representam o momento da adição, não a duração do processo. Esse dataframe complementa o `data_bulk`, mostrando *quando* cada material entrou no processo.
#
# ---
#
# ### 4- No dataframe data_gas, o que significam os valores de Gas 1? Se referem a uma etapa específica do processo? Se sim, qual? Qual é este gás e qual a unidade de medida?
#
# A coluna `Gas 1` representa o consumo total de gás por lote. Em geral, está associada a etapas contínuas do processo, como aquecimento ou manutenção de temperatura.
#
# O tipo exato de gás e a unidade de medida não ficam claros apenas pelos dados e dependem da documentação do processo. Mesmo assim, a variável é útil como consumo agregado por lote.
#
# ---
#
# ### 5- No dataframe data_temp, o que significam valores nulos de temperatura? Para cada lote há mais de um valor, isso representa o valor de temperatura para cada etapa do processo? Se não, o que significam?
#
# Cada linha é uma medição de temperatura em um momento específico. Um mesmo lote tem várias medições porque a temperatura é registrada ao longo do tempo, e não por etapa.
#
# Os valores nulos indicam ausência de leitura válida do sensor e não representam uma etapa do processo. Eles devem ser analisados e tratados conforme o objetivo da análise.
#
# ---
#
# ### 6- No dataframe data_wire, o que significa cada coluna? O que significam os valores em branco? Há sentido em somar todos para cada lote?
#
# Cada linha representa um lote e as colunas `Wire 1` a `Wire 9` indicam a quantidade de cada tipo de arame utilizada. Valores em branco indicam que o arame não foi usado naquele lote.
#
# Somar os valores por lote é útil para obter o total de arame, mas a análise individual de cada tipo também é importante, pois eles podem ter impactos diferentes no processo.
#
# ---
#
# ### 7- No dataframe data_wire_tim, o que significa cada coluna? Os valores datetime referem-se a que, exatamente?
#
# Cada linha representa um lote, e as colunas indicam o horário em que cada tipo de wire foi adicionado. Valores preenchidos mostram o momento exato da adição; valores `NaN` indicam que o wire não foi utilizado.
#
# ---
#
# ### 8- O valor-objetivo da análise deverá ser uma **temperatura**. Qual valor de temperatura devemos utilizar como target? Seria a coluna df_data_temp['Temperature']? Deseja-se entender a temperatura de alguma etapa específica do processo, de todas ou a diferença de temperatura entre eles (qual abordagem entregaria maior ganho?)
#
# Não é indicado usar diretamente `df_data_temp['Temperature']`, pois há várias medições por lote. Para o modelo, é necessário um único valor por lote.
#
# A abordagem mais clara é usar a **última temperatura válida de cada lote**, pois ela representa o estado final do processo. Outras métricas (máxima, média ou variação) podem ser usadas como features auxiliares.
#
# ---
#
# ### 9- Devemos utilizar o tempo como Feature? No caso, seria o valor bruto ou a diferença entre os horários de cada etapa produtiva?
#
# Sim, o tempo pode ser usado como feature. Tanto os valores brutos quanto as diferenças entre eventos podem ser testados, e o impacto deve ser avaliado durante a modelagem.
#
# ---
#
# ### 10- Há alguma variável que possivelmente tem um peso maior ou menor na análise? Alguma deve ser desconsiderada?
#
# Isso deve ser definido a partir de análises como correlação e feature importance. Com base nesses resultados, é possível identificar quais variáveis são mais relevantes.
#
# ---
#
# ### 11- Existe algum método preditivo específico preferido pelo cliente ou devemos escolher mediante a construção do projeto?
#
# A escolha do modelo é responsabilidade do profissional de dados. O ideal é testar abordagens diferentes e selecionar a que melhor se adapta ao problema.
#
# ---
#
# ### 12- Como devemos calcular o potencial de ganho com o projeto?
#
# O ganho deve ser estimado a partir do impacto do modelo no processo real, como melhoria de qualidade, redução de custos, economia de energia ou diminuição de retrabalho, sempre alinhado aos objetivos do negócio.

# %% [markdown]
# ### Plano de resulução
#
# A atividade será executada nas seguintes principais etapas:
#
# 1 - Criação de documento orientativo: documento apresentando objetivo, motivação, contexto geral da atividade, análise exploratória de dados e plano de resolução geral do projeto (documento atual);
#
# 2 - Tratamento dos dados: tratamento dos dados que serão utilizados como features e target da análise preditiva, como também criação de dataframe base para aplicação dos métodos;
#
# 3 - Treinamento do modelo: aplicação de modelos preditivos de regressão como LightGBM ou CatBoost para o conjunto de dados;
#
# 4 - Validação dos modelos: aplicação do modelo treinado em conjunto de validação;
#
# 5 - Conclusão: conclusões extraídas e potencial de ganho calculado.
